# %%
import pandas as pd
from pandas import Series
from pandas import DataFrame

# %%
df = pd.read_csv('D:/spider/1.csv', encoding='gbk')

# %%
df
# Out:
#      Unnamed: 0      City           NickName    Province  Sex  \
# 0             0        吉林             像风一样自由          吉林    1
# 1             1        吉林                 阿静          吉林    2
# 2             2        长春           你的回眸……勾…          吉林    1
# 3             3        吉林                孙明伟          吉林    1
# 4             4       石家庄             a+b+c+          河北    1
# 5             5        昌平                 一庥          北京    1
# 6             6        吉林                  .          吉林    1
# 7             7        昌平                 韩瑞          北京    1
# 8             8       NaN                 穆峰          北京    1
# 9             9       NaN                笨小孩          北京    1
# 10           10        眉山                 解凯          四川    1
# 11           11        昌平                杨自华          北京    1
# 12           12        吉林              浅笑ソ安然          吉林    1
# 13           13        运城                est          山西    1
# ...

# %%
group = df.groupby(['Province', 'City'])

# %%
group.size()
# Out:
# Province     City
# England      London          1
# Grand Forks  Grand Forks     1
# New York     New York        1
# 上海           普陀              1
# 云南           丽江              1
# 北京           丰台              1
#              房山              1
#              昌平             25
#              朝阳              7
#              海淀              3
#              石景山             1
#              顺义              1
# 吉林           吉林             28
#              延边              1
#              长春              5
# 四川           眉山              1
# 安徽           合肥              1
#              安庆              1
# 山东           东营              1
# 山西           临汾              1
#              运城              1
#              阳泉              1
# 广东           佛山              1
#              广州              1
#              汕头              1
#              深圳              2
# 新疆           克孜勒苏            1
# 江苏           南通              1
#              泰州              1
# ...

# %%
import numpy as np

# %%
import matplotlib.pylab as plt

# %%
def step_function(a):
    return np.array(a > 0, dtype=int)

# %%
x = np.arange(-5.0, 5.0, 0.1)

# %%
y = step_function(x)

# %%
plt.plot(x, y)

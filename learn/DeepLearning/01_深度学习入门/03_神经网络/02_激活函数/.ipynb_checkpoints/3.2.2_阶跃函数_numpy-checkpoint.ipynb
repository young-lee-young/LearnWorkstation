# %%
import numpy as np

# %%
x = np.array([-1.0, 1.0, 2.0])

# %%
x
# Out:
# array([-1.,  1.,  2.])

# %%
y = x > 0

# %%
y
# Out:
# array([False,  True,  True])

# %%
y = y.astype(int)

# %%
y
# Out:
# array([0, 1, 1])
